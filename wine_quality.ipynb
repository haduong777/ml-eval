# %% [markdown]
# ## <b>DATA</b>

# %%
from ucimlrepo import fetch_ucirepo 
from joblib import dump, load
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
# fetch dataset 
wine_quality = fetch_ucirepo(id=186) 
  
# data (as pandas dataframes) 
X = wine_quality.data.features 
y = wine_quality.data.targets

# %%
# sepsis features
X.head(5)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
# sepsis targets
y.head(5)
# Out:
#    quality
# 0        5
# 1        5
# 2        5
# 3        6
# 4        5

# %%
y['quality'].value_counts()
# Out:
# quality
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: count, dtype: int64

# %%
# make binary and ravel

y_encode = y.copy()
y_encode['quality'] = (y['quality'] >= 6).astype(float)

y_n = np.array(y_encode).ravel()

y_n
# Out:
# array([0., 0., 0., ..., 1., 1., 1.])

# %%
# normalizing
scaler = StandardScaler()
X_n = scaler.fit_transform(X)

# %%
X_n
# Out:
# array([[ 0.14247327,  2.18883292, -2.19283252, ...,  1.81308951,
#          0.19309677, -0.91546416],
#        [ 0.45103572,  3.28223494, -2.19283252, ..., -0.11507303,
#          0.99957862, -0.58006813],
#        [ 0.45103572,  2.55330026, -1.91755268, ...,  0.25811972,
#          0.79795816, -0.58006813],
#        ...,
#        [-0.55179227, -0.6054167 , -0.88525328, ..., -1.42124765,
#         -0.47897144, -0.91546416],
#        [-1.32319841, -0.30169391, -0.12823371, ...,  0.75571005,
#         -1.016626  ,  1.9354021 ],
#        [-0.93749534, -0.78765037,  0.42232597, ...,  0.25811972,
#         -1.41986693,  1.09691202]])

# %% [markdown]
# ## <b>Gradient Boosting (XGBoost)</b>

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score
from imblearn.over_sampling import SMOTE

# %%
# split data
X_train, X_test, y_train, y_test = train_test_split(X_n, y_n, test_size=0.2, random_state=42, shuffle=True)

# experiment with class weights or SMOTE
# SMOTE - oversample minority class
smote = SMOTE(random_state=42, k_neighbors=1)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
#base model
xgb_base = XGBClassifier(eval_metric='logloss',
                         objective='binary:logistic',
                         reg_alpha = 0.5,
                         reg_lambda=5,
                         random_state=42)

# tune hyperparameters with gridsearch
param_grid = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3,7, 10]
}

grid_search = GridSearchCV(
    estimator= xgb_base,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=5,
    verbose=1
) 

grid_search.fit(X_train_smote, y_train_smote)

print("Best Parameters:", grid_search.best_params_)
print("Best ROC-AUC:", grid_search.best_score_)

#consider class-specific thresholds
#precision, recall, thresholds = precision_recall_curve(y_test, y_pred_proba[:, class_index])
#optimal_threshold = thresholds[np.argmax(precision * recall)]
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 200}
# Best ROC-AUC: 0.9330686240105287

# %%
# train on 3 splits
for test_size in [0.2,0.5, 0.8]:
    X_train, X_test, y_train, y_test = train_test_split(X_n, y_n, test_size=test_size,shuffle=True, random_state=42)
    
    # create model with optimal params
    xgb_opt = XGBClassifier(
        eval_metric='mlogloss',
        **grid_search.best_params_,
        random_state=42
    )
    
    xgb_opt.fit(X_train, y_train)
    
    y_pred_proba = xgb_opt.predict_proba(X_test)[:,1]
    y_pred_class = xgb_opt.predict(X_test)
    
    print("Train="+str(round(1-test_size,2)))
    print(classification_report(y_test, y_pred_class,zero_division=0))
    
    # ROC-AUC for multiclass MODIFY TMR
    try:
        roc_auc = roc_auc_score(y_test, y_pred_proba)  
        print(f"ROC-AUC: {roc_auc:.4f}")
    except ValueError as e:
        print(f"Could not calculate ROC-AUC: {e}")
        
    print(" ")
    print(" ")
# Out:
# Train=0.8
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.72      0.72       451
#          1.0       0.85      0.86      0.86       849
#
#     accuracy                           0.81      1300
#    macro avg       0.79      0.79      0.79      1300
# weighted avg       0.81      0.81      0.81      1300
#
# ROC-AUC: 0.8667
#
#
# Train=0.5
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.72      0.72      1157
#          1.0       0.84      0.84      0.84      2092
#
#     accuracy                           0.80      3249
#    macro avg       0.78      0.78      0.78      3249
# weighted avg       0.80      0.80      0.80      3249
#
# ROC-AUC: 0.8600
#
#
# Train=0.2
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.68      0.67      1900
#          1.0       0.81      0.81      0.81      3298
#
#     accuracy                           0.76      5198
#    macro avg       0.74      0.74      0.74      5198
# weighted avg       0.76      0.76      0.76      5198
#
# ROC-AUC: 0.8186

# %%
# save the model

dump(xgb_opt, "trained/xgb_opt_WINE.joblib")
# Out:
# ['trained/xgb_opt_WINE.joblib']

# %% [markdown]
# ## <b>NEURALNET</b>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, BatchNormalization, Input
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import EarlyStopping
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split, GridSearchCV
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score,classification_report, roc_auc_score, roc_curve
from sklearn.preprocessing import label_binarize

# %%
# Split 80/20 train/test
X_normed_nn = scaler.fit_transform(X_n)
X_normed_nn

# splitting NORMED data
X_train, X_test, y_train, y_test = train_test_split(X_normed_nn, y_n, test_size=0.2, random_state=42,shuffle=True)

# Oversample the minority classes
smote = SMOTE(random_state=42, k_neighbors=1)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
def create_nn(learning_rate=0.001):
    model = Sequential([Input(shape=(11,)),
                        Dense(64, activation="relu"),
                        Dense(32, activation="relu"), 
                        Dense(1, activation="sigmoid")]) # output layer
    
    model.compile(optimizer = Adam(learning_rate=learning_rate),
                  loss = "binary_crossentropy",
                  metrics = ["accuracy"])
                  
    return model

# %%
# Keras wrapper -> use gridsearchcv with neuralnet

nn = KerasClassifier(model=create_nn)

# %%
# Gridsearchcv

param_grid = {
    'model__learning_rate': [0.001, 0.01],
    'batch_size': [64, 128, 256]
}

grid_search = GridSearchCV(
    estimator=nn,
    param_grid=param_grid,
    scoring="accuracy",
    cv=5,
    n_jobs=4     #parallel = 4 cores
) 

# early stop
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

grid_search.fit(
    X_train_smote,
    y_train_smote,
    epochs=200,
    callbacks=[early_stop]
)

print("Best Parameters:", grid_search.best_params_)
print("Best Accuracy:", grid_search.best_score_)
# Out:
# Epoch 1/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.6990 - loss: 0.5660
# Epoch 2/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - accuracy: 0.7706 - loss: 0.4973
# Epoch 3/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - accuracy: 0.7732 - loss: 0.4929
# Epoch 4/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - accuracy: 0.7815 - loss: 0.4714
# Epoch 5/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.7766 - loss: 0.4717
# Epoch 6/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - accuracy: 0.7870 - loss: 0.4590
# Epoch 7/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - accuracy: 0.7920 - loss: 0.4517
# Epoch 8/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.7924 - loss: 0.4446
# Epoch 9/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.8036 - loss: 0.4245
# Epoch 10/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.8129 - loss: 0.4163
# Epoch 11/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - accuracy: 0.8123 - loss: 0.4195
# Epoch 12/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - accuracy: 0.8038 - loss: 0.4175
# Epoch 13/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - accuracy: 0.8046 - loss: 0.4268
# Epoch 14/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - accuracy: 0.8209 - loss: 0.4018
# Epoch 15/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8166 - loss: 0.4007
# Epoch 16/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8221 - loss: 0.3915
# Epoch 17/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 0.8257 - loss: 0.3840
# Epoch 18/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 0.8271 - loss: 0.3865
# Epoch 19/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - accuracy: 0.8277 - loss: 0.3852
# Epoch 20/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - accuracy: 0.8358 - loss: 0.3677
# Epoch 21/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.8305 - loss: 0.3707
# Epoch 22/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8399 - loss: 0.3541
# Epoch 23/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.8376 - loss: 0.3546
# Epoch 24/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 0.8489 - loss: 0.3401
# Epoch 25/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - accuracy: 0.8476 - loss: 0.3465
# Epoch 26/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - accuracy: 0.8557 - loss: 0.3370
# Epoch 27/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - accuracy: 0.8467 - loss: 0.3420
# Epoch 28/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.8577 - loss: 0.3218
# Epoch 29/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - accuracy: 0.8534 - loss: 0.3328
# Epoch 30/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - accuracy: 0.8540 - loss: 0.3251
# Epoch 31/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - accuracy: 0.8541 - loss: 0.3215
# Epoch 32/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 0.8649 - loss: 0.3091
# Epoch 33/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - accuracy: 0.8704 - loss: 0.2993
# Epoch 34/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - accuracy: 0.8730 - loss: 0.2853
# Epoch 35/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8699 - loss: 0.2939
# Epoch 36/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - accuracy: 0.8708 - loss: 0.2968
# Epoch 37/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - accuracy: 0.8779 - loss: 0.2809
# Epoch 38/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.8749 - loss: 0.2858
# Epoch 39/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - accuracy: 0.8871 - loss: 0.2808
# Epoch 40/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - accuracy: 0.8884 - loss: 0.2691
# Epoch 41/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - accuracy: 0.8790 - loss: 0.2745
# Epoch 42/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - accuracy: 0.8890 - loss: 0.2683
# Epoch 43/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - accuracy: 0.
200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9709 - loss: 0.0854
# Epoch 183/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.9612 - loss: 0.0988
# Epoch 184/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - accuracy: 0.9661 - loss: 0.0925
# Epoch 185/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9577 - loss: 0.1271
# Epoch 186/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - accuracy: 0.9608 - loss: 0.1106
# Epoch 187/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - accuracy: 0.9610 - loss: 0.1223
# Epoch 188/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9632 - loss: 0.0946
# Epoch 189/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - accuracy: 0.9673 - loss: 0.0834
# Epoch 190/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - accuracy: 0.9734 - loss: 0.0773
# Epoch 191/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9657 - loss: 0.0908
# Epoch 192/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - accuracy: 0.9752 - loss: 0.0725
# Epoch 193/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - accuracy: 0.9787 - loss: 0.0657
# Epoch 194/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9709 - loss: 0.0824
# Epoch 195/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - accuracy: 0.9589 - loss: 0.1010
# Epoch 196/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - accuracy: 0.9723 - loss: 0.0726
# Epoch 197/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9722 - loss: 0.0773
# Epoch 198/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - accuracy: 0.9721 - loss: 0.0778
# Epoch 199/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - accuracy: 0.9715 - loss: 0.0774
# Epoch 200/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9758 - loss: 0.0650
# Best Parameters: {'batch_size': 128, 'model__learning_rate': 0.01}
# Best Accuracy: 0.8393214929033697

# %%
# train on 3 splits
for test_size in [0.2,0.5, 0.8]:
    X_train, X_test, y_train, y_test = train_test_split(X_normed_nn, y_n, test_size=test_size, random_state=42,shuffle=True)
    
    # create model with optimal learning rate
    nn_opt = create_nn(
        learning_rate=grid_search.best_params_['model__learning_rate']
    )
    
    nn_opt.fit(X_train, y_train,
               batch_size=grid_search.best_params_['batch_size'],
               epochs=200,
               validation_split=0.2,
               callbacks=[early_stop])

    y_pred_proba = nn_opt.predict(X_test)
    y_pred_class = (y_pred_proba >= 0.5).astype(float)
      
    print("Train="+str(round(1-test_size)))
    print(f"ROC-AUC: {roc_auc_score(y_test, y_pred_proba, multi_class='ovr'):.4f}")
    print(" ")
    print(" ")
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6323 - loss: 0.6239 - val_accuracy: 0.7683 - val_loss: 0.4786
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7536 - loss: 0.5017 - val_accuracy: 0.7635 - val_loss: 0.4767
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7608 - loss: 0.4934 - val_accuracy: 0.7875 - val_loss: 0.4551
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7808 - loss: 0.4743 - val_accuracy: 0.7942 - val_loss: 0.4589
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7738 - loss: 0.4692 - val_accuracy: 0.7788 - val_loss: 0.4619
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7786 - loss: 0.4670 - val_accuracy: 0.7798 - val_loss: 0.4671
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7743 - loss: 0.4694 - val_accuracy: 0.7779 - val_loss: 0.4547
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7896 - loss: 0.4567 - val_accuracy: 0.7913 - val_loss: 0.4567
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7882 - loss: 0.4464 - val_accuracy: 0.7750 - val_loss: 0.4556
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7887 - loss: 0.4424 - val_accuracy: 0.7962 - val_loss: 0.4436
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7946 - loss: 0.4394 - val_accuracy: 0.7865 - val_loss: 0.4406
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7902 - loss: 0.4445 - val_accuracy: 0.7952 - val_loss: 0.4446
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7942 - loss: 0.4291 - val_accuracy: 0.7740 - val_loss: 0.4555
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8100 - loss: 0.4151 - val_accuracy: 0.7846 - val_loss: 0.4438
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7935 - loss: 0.4388 - val_accuracy: 0.7885 - val_loss: 0.4604
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8058 - loss: 0.4165 - val_accuracy: 0.7865 - val_loss: 0.4490
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8119 - loss: 0.4091 - val_accuracy: 0.7894 - val_loss: 0.4498
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.
# Epoch 27/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8412 - loss: 0.3617 - val_accuracy: 0.8092 - val_loss: 0.4505
# Epoch 28/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8372 - loss: 0.3564 - val_accuracy: 0.7985 - val_loss: 0.4341
# Epoch 29/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8440 - loss: 0.3444 - val_accuracy: 0.7908 - val_loss: 0.4469
# Epoch 30/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8528 - loss: 0.3387 - val_accuracy: 0.7846 - val_loss: 0.4614
# Epoch 31/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8515 - loss: 0.3407 - val_accuracy: 0.8046 - val_loss: 0.4360
# Epoch 32/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8429 - loss: 0.3426 - val_accuracy: 0.7938 - val_loss: 0.4701
# Epoch 33/200
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8455 - loss: 0.3244 - val_accuracy: 0.7954 - val_loss: 0.4643
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step
# Train=0
# ROC-AUC: 0.8316
#
#
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6496 - loss: 0.6105 - val_accuracy: 0.7923 - val_loss: 0.4519
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7584 - loss: 0.5171 - val_accuracy: 0.8000 - val_loss: 0.4577
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7760 - loss: 0.4688 - val_accuracy: 0.8192 - val_loss: 0.4451
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7616 - loss: 0.4749 - val_accuracy: 0.8077 - val_loss: 0.4565
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7648 - loss: 0.4718 - val_accuracy: 0.8154 - val_loss: 0.4313
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7704 - loss: 0.4709 - val_accuracy: 0.8231 - val_loss: 0.4339
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7768 - loss: 0.4538 - val_accuracy: 0.8346 - val_loss: 0.4430
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8093 - loss: 0.4325 - val_accuracy: 0.8385 - val_loss: 0.4345
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7947 - loss: 0.4480 - val_accuracy: 0.8269 - val_loss: 0.4349
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7989 - loss: 0.4221 - val_accuracy: 0.8077 - val_loss: 0.4399
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7728 - loss: 0.4408 - val_accuracy: 0.8308 - val_loss: 0.4266
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8028 - loss: 0.4129 - val_accuracy: 0.8115 - val_loss: 0.4335
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8199 - loss: 0.4032 - val_accuracy: 0.8192 - val_loss: 0.4307
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8093 - loss: 0.3948 - val_accuracy: 0.8038 - val_loss: 0.4503
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8276 - loss: 0.3759 - val_accuracy: 0.8385 - val_loss: 0.4242
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8160 - loss: 0.3860 - val_accuracy: 0.8038 - val_loss: 0.4502
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8444 - loss: 0.3540 - val_accuracy: 0.8231 - val_loss: 0.4245
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8278 - loss: 0.3640 - val_accuracy: 0.8077 - val_loss: 0.4569
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8249 - loss: 0.3660 - val_accuracy: 0.8154 - val_loss: 0.4244
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8437 - loss: 0.3345 - val_accuracy: 0.8115 - val_loss: 0.4358
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8511 - loss: 0.3263 - val_accuracy: 0.8115 - val_loss: 0.4649
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8539 - loss: 0.3264 - val_accuracy: 0.8154 - val_loss: 0.4279
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8638 - loss: 0.3094 - val_accuracy: 0.8154 - val_loss: 0.4866
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8281 - loss: 0.3563 - val_accuracy: 0.7962 - val_loss: 0.4452
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8386 - loss: 0.3414 - val_accuracy: 0.7962 - val_loss: 0.4676
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step
# Train=0
# ROC-AUC: 0.8023

# %%
# save the model

dump(nn_opt, "trained/nn_opt_WINE.joblib")
# Out:
# ['trained/nn_opt_WINE.joblib']

# %% [markdown]
# ## <b>RandomForest</b>

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score
from imblearn.over_sampling import SMOTE

# %%
# Split 80/20 train/test
X_train, X_test, y_train, y_test = train_test_split(X_n, y_n, test_size=0.2, random_state=42,shuffle=True)

# Oversample the minority classes
smote = SMOTE(random_state=42,  k_neighbors=1)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
# gridsearchcv
param_grid = {
    'n_estimators': [50, 100, 200], #100 200
    'max_depth': [10, 20],
    'min_samples_split': [2, 5]
}

grid_search = GridSearchCV(
    RandomForestClassifier(random_state=42), 
    param_grid, 
    cv=3, 
    scoring='roc_auc',
    verbose=1,
    n_jobs=4
)

grid_search.fit(X_train_smote, y_train_smote)
print("Best Parameters:", grid_search.best_params_)
print("Best ROC-AUC:", grid_search.best_score_)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best Parameters: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 200}
# Best ROC-AUC: 0.9369413206459054

# %%
# Check most 'influential' feature to predict the target
feature_importances = grid_search.best_estimator_.feature_importances_
feature_importances
# Out:
# array([0.06392109, 0.12212682, 0.07227384, 0.07204164, 0.08186791,
#        0.0788032 , 0.07932974, 0.10037574, 0.06726297, 0.07764814,
#        0.18434892])

# %%
#Train model with best parameters on 3 different splits

for test_size in [0.2,0.5, 0.8]:
    X_train, X_test, y_train, y_test = train_test_split(X_n, y_n, test_size=test_size, random_state=42,shuffle=True)    
    
    rf_opt = RandomForestClassifier(**grid_search.best_params_, random_state=42)
    
    rf_opt.fit(X_train, y_train)
    
    y_pred = rf_opt.predict(X_test)
    y_pred_proba = rf_opt.predict_proba(X_test)[:,1]
    
    print("Train="+str(round(1-test_size,2)))
    print(classification_report(y_test, y_pred, zero_division=0))
    print(f"ROC-AUC: {roc_auc_score(y_test, y_pred_proba):.4f}")
    print(" ")
    print(" ")
# Out:
# Train=0.8
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.73      0.74       451
#          1.0       0.86      0.87      0.86       849
#
#     accuracy                           0.82      1300
#    macro avg       0.80      0.80      0.80      1300
# weighted avg       0.82      0.82      0.82      1300
#
# ROC-AUC: 0.8896
#
#
# Train=0.5
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.73      0.73      1157
#          1.0       0.85      0.85      0.85      2092
#
#     accuracy                           0.81      3249
#    macro avg       0.79      0.79      0.79      3249
# weighted avg       0.81      0.81      0.81      3249
#
# ROC-AUC: 0.8792
#
#
# Train=0.2
#               precision    recall  f1-score   support
#
#          0.0       0.69      0.66      0.67      1900
#          1.0       0.81      0.83      0.82      3298
#
#     accuracy                           0.77      5198
#    macro avg       0.75      0.74      0.75      5198
# weighted avg       0.76      0.77      0.77      5198
#
# ROC-AUC: 0.8363

# %%
# save the model

dump(rf_opt, "trained/rf_opt_WINE.joblib")
# Out:
# ['trained/rf_opt_WINE.joblib']

# %% [markdown]
# ## <b>SGDClassifier (SVM approximation)</b>

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Split 80/20 train/test

# splitting NORMED data
X_train, X_test, y_train, y_test = train_test_split(X_normed_nn, y_n, test_size=0.2, random_state=42,shuffle=True)

# Oversample the minority class
smote = SMOTE(random_state=42,k_neighbors=1)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
# base model
sgd = SGDClassifier(
    learning_rate='optimal',
    penalty='elasticnet',
    max_iter=200,
    random_state=42
)

#gridsearch
param_grid = {
    'alpha' : [1e-5, 1e-3, 1e-1],
    'l1_ratio': [0.15,0.5, 0.85],
    'tol' : [1e-5, 1e-6],
    'loss': ['log_loss']
}

grid_search = GridSearchCV(
    estimator=sgd,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=5,
    verbose=1,
    n_jobs=4
)

grid_search.fit(X_train_smote, y_train_smote)

# Best parameters and evaluation
print("Best Parameters:", grid_search.best_params_)
print("Best ROC-AUC:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best Parameters: {'alpha': 0.001, 'l1_ratio': 0.85, 'loss': 'log_loss', 'tol': 1e-05}
# Best ROC-AUC: 0.805214371432065

# %%
for test_size in [0.2,0.5, 0.8]:
    X_train, X_test, y_train, y_test = train_test_split(X_n, y_n, test_size=test_size, random_state=42,shuffle=True)    
    
    sgd_opt = SGDClassifier(
        **grid_search.best_params_, 
        learning_rate='optimal',
        penalty='elasticnet',
        max_iter=1000,
        random_state=42
    )
    
    sgd_opt.fit(X_train, y_train)
    
    y_pred = sgd_opt.predict(X_test)
    y_pred_proba = sgd_opt.predict_proba(X_test)[:,1]
    
    print("Train="+str(round(1 - test_size, 2)))
    print(classification_report(y_test, y_pred, zero_division=0))
    print(f"ROC-AUC: {roc_auc_score(y_test, y_pred_proba):.4f}")
    print(" ")
    print(" ")
# Out:
# Train=0.8
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.59      0.60       451
#          1.0       0.79      0.79      0.79       849
#
#     accuracy                           0.72      1300
#    macro avg       0.69      0.69      0.69      1300
# weighted avg       0.72      0.72      0.72      1300
#
# ROC-AUC: 0.7784
#
#
# Train=0.5
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.55      0.60      1157
#          1.0       0.77      0.84      0.80      2092
#
#     accuracy                           0.74      3249
#    macro avg       0.71      0.70      0.70      3249
# weighted avg       0.73      0.74      0.73      3249
#
# ROC-AUC: 0.7907
#
#
# Train=0.2
#               precision    recall  f1-score   support
#
#          0.0       0.64      0.62      0.63      1900
#          1.0       0.79      0.80      0.79      3298
#
#     accuracy                           0.73      5198
#    macro avg       0.71      0.71      0.71      5198
# weighted avg       0.73      0.73      0.73      5198
#
# ROC-AUC: 0.7833

# %%
# save the model

dump(sgd_opt, "trained/sgd_opt_WINE.joblib")
# Out:
# ['trained/sgd_opt_WINE.joblib']

# %% [markdown]
# ## <b>Ensemble (Meta-model = SVM)</b>

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_auc_score

# %%
# split data
X_train, X_test, y_train, y_test = train_test_split(X_n, y_n, test_size=0.2, random_state=42)    

# all pretrained models
base_models = [sgd_opt, rf_opt, nn_opt, xgb_opt]

# make meta features
meta_trainl = []
meta_testl = []

for model in base_models:
    if hasattr(model, "predict_proba"):
        meta_trainl.append(model.predict_proba(X_train)[:,1])
        meta_testl.append(model.predict_proba(X_test)[:,1])
    else:
        meta_trainl.append(model.predict(X_train).ravel())
        meta_testl.append(model.predict(X_test).ravel())    #NN doesnt have predict proba

meta_train = np.array(meta_trainl).T
meta_test = np.array(meta_testl).T
# Out:
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step

# %%
svm_meta = SVC(kernel='rbf', probability=True, random_state=42)

param_grid = {
    'C' : [0.1, 1, 10],
    'gamma': [0.01, 0.1, 1]
}

grid_search = GridSearchCV(
    estimator=svm_meta,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=5,  # Inner cross-validation
    verbose=2,
    n_jobs=-1
)

# Fit the meta-model using GridSearchCV
grid_search.fit(meta_train, y_train)

# Best parameters and evaluation
print("Best Parameters:", grid_search.best_params_)
print("Best ROC-AUC:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Best Parameters: {'C': 0.1, 'gamma': 0.01}
# Best ROC-AUC: 0.8797707033252085

# %%
for test_size in [0.2,0.5, 0.8]:
    # split data
    X_train, X_test, y_train, y_test = train_test_split(X_n, y_n, test_size=test_size, random_state=42,shuffle=True)    

    meta_trainl=[]
    meta_testl=[]
    
    for model in base_models:
        if hasattr(model, "predict_proba"):
            meta_trainl.append(model.predict_proba(X_train)[:,1])
            meta_testl.append(model.predict_proba(X_test)[:,1])
        else:
            meta_trainl.append(model.predict(X_train).ravel())
            meta_testl.append(model.predict(X_test).ravel())    #NN doesnt have predict proba
    
    meta_train = np.array(meta_trainl).T
    meta_test = np.array(meta_testl).T
    
    svm_meta_opt = SVC(
        **grid_search.best_params_, 
        probability=True,
        random_state=42
    )
    
    svm_meta_opt.fit(meta_train, y_train)
    
    y_pred = svm_meta_opt.predict(meta_test)
    y_pred_proba = svm_meta_opt.predict_proba(meta_test)[:,1]
    
    print("Train="+str(round(1 - test_size, 2)))
    print(classification_report(y_test, y_pred, zero_division=0))
    print(f"ROC-AUC: {roc_auc_score(y_test, y_pred_proba):.4f}")
    print(" ")
    print(" ")
# Out:
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Train=0.8
#               precision    recall  f1-score   support
#
#          0.0       0.63      0.67      0.65       451
#          1.0       0.82      0.79      0.80       849
#
#     accuracy                           0.75      1300
#    macro avg       0.72      0.73      0.72      1300
# weighted avg       0.75      0.75      0.75      1300
#
# ROC-AUC: 0.8155
#
#
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Train=0.5
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.68      0.67      1157
#          1.0       0.82      0.82      0.82      2092
#
#     accuracy                           0.77      3249
#    macro avg       0.75      0.75      0.75      3249
# weighted avg       0.77      0.77      0.77      3249
#
# ROC-AUC: 0.8323
#
#
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Train=0.2
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.65      0.67      1900
#          1.0       0.81      0.84      0.82      3298
#
#     accuracy                           0.77      5198
#    macro avg       0.75      0.74      0.75      5198
# weighted avg       0.77      0.77      0.77      5198
#
# ROC-AUC: 0.8314

# %%
# save the model

dump(svm_meta_opt, "trained/svm_meta_opt_WINE.joblib")
# Out:
# ['trained/svm_meta_opt_WINE.joblib']
