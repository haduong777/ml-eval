# %% [markdown]
# ## <b>DATA</b>

# %%
from ucimlrepo import fetch_ucirepo 
from joblib import dump, load
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
# fetch dataset 
sepsis_survival_minimal_clinical_records = fetch_ucirepo(id=827) 
  
# data (as pandas dataframes) 
X = sepsis_survival_minimal_clinical_records.data.features 
y = sepsis_survival_minimal_clinical_records.data.targets

# %%
# sepsis features
X
# Out:
#         age_years  sex_0male_1female  episode_number
# 0              21                  1               1
# 1              20                  1               1
# 2              21                  1               1
# 3              77                  0               1
# 4              72                  0               1
# ...           ...                ...             ...
# 110336         47                  0               1
# 110337         50                  0               1
# 110338         62                  0               1
# 110339         58                  0               1
# 110340         55                  1               1
#
# [110341 rows x 3 columns]

# %%
# sepsis targets
y.head(5)
# Out:
#    hospital_outcome_1alive_0dead
# 0                              1
# 1                              1
# 2                              1
# 3                              1
# 4                              1

# %%
# Separating Norway data and Korean data - train on Norway, test on Korea for generalization

X_n = X[:-137] 
y_n = y[:-137]

X_k = X[-137:].reset_index(drop=True)
y_k = y[-137:].reset_index(drop=True)

# %%
# normalizing
scaler = StandardScaler()
X_num_scaled = scaler.fit_transform(X_n[['age_years', 'episode_number']])

X_normed = X_n.copy()
X_normed['age_years'] = X_num_scaled[:,0]
X_normed['episode_number'] = X_num_scaled[:,1]

X_normed.head()
# Out:
#    age_years  sex_0male_1female  episode_number
# 0  -1.729837                  1       -0.464727
# 1  -1.771285                  1       -0.464727
# 2  -1.729837                  1       -0.464727
# 3   0.591243                  0       -0.464727
# 4   0.384004                  0       -0.464727

# %% [markdown]
# ## <b>Gradient Boosting (XGBoost)</b>

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_auc_score, roc_curve
from imblearn.over_sampling import SMOTE

# %%
y_ravel = y_n.values.ravel()

X_train, X_test, y_train, y_test = train_test_split(X_normed, y_ravel, test_size=0.2, random_state=42,shuffle=True)

# %%
# SMOTE - oversample minority class
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

#base model
xgb_base = XGBClassifier(eval_metric='logloss',
                         objective='binary:logistic',
                         reg_alpha = 0.5,
                         reg_lambda=5,
                         random_state=42)

# tune hyperparameters with gridsearch
param_grid = {
    'n_estimators': [100, 200],
    'learning_rate': [0.01, 0.1],
    'max_depth': [3,7, 10]
}

grid_search = GridSearchCV(
    estimator= xgb_base,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=5,
    verbose=1,
    n_jobs=-1 #parallel process
) 

grid_search.fit(X_train_smote, y_train_smote)

print("Best Parameters:", grid_search.best_params_)
print("Best ROC-AUC:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best Parameters: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 200}
# Best ROC-AUC: 0.7328670227896773

# %%
# train on 3 splits
for test_size in [0.2,0.5, 0.8]:
    X_train, X_test, y_train, y_test = train_test_split(X_normed, y_ravel, test_size=test_size, random_state=42,shuffle=True)
    
    # create model with optimal params
    xgb_opt = XGBClassifier(
        eval_metric='mlogloss',
        **grid_search.best_params_,
        random_state=42
    )
    
    xgb_opt.fit(X_train, y_train)
    
    y_pred_proba = xgb_opt.predict_proba(X_test)[:,1]
    
    y_pred_class = xgb_opt.predict(X_test)
    
    print("Train="+str(round(1-test_size,2)))
    print(classification_report(y_test, y_pred_class,zero_division=0))
    

    try:
        roc_auc = roc_auc_score(y_test, y_pred_proba)  # One-vs-rest
        print(f"ROC-AUC: {roc_auc:.4f}")
    except ValueError as e:
        print(f"Could not calculate ROC-AUC: {e}")
        
    print(" ")
    print(" ")
# Out:
# Train=0.8
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1613
#            1       0.93      1.00      0.96     20428
#
#     accuracy                           0.93     22041
#    macro avg       0.46      0.50      0.48     22041
# weighted avg       0.86      0.93      0.89     22041
#
# ROC-AUC: 0.6931
#
#
# Train=0.5
#               precision    recall  f1-score   support
#
#            0       0.33      0.00      0.00      4062
#            1       0.93      1.00      0.96     51040
#
#     accuracy                           0.93     55102
#    macro avg       0.63      0.50      0.48     55102
# weighted avg       0.88      0.93      0.89     55102
#
# ROC-AUC: 0.6903
#
#
# Train=0.2
#               precision    recall  f1-score   support
#
#            0       0.14      0.00      0.00      6533
#            1       0.93      1.00      0.96     81631
#
#     accuracy                           0.93     88164
#    macro avg       0.53      0.50      0.48     88164
# weighted avg       0.87      0.93      0.89     88164
#
# ROC-AUC: 0.6847

# %%
# save the model

dump(xgb_opt, "trained/xgb_opt_SEPSIS.joblib")
# Out:
# ['trained/xgb_opt_SEPSIS.joblib']

# %% [markdown]
# ## <b>NEURALNET</b>

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, BatchNormalization, Input
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import EarlyStopping
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split, GridSearchCV
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, roc_auc_score, roc_curve

# %%
# Split 80/20 train/test

y_ravel = y_n.values.ravel()

X_normed_nn = scaler.fit_transform(X_n)
X_normed_nn

# splitting NORMED data
X_train, X_test, y_train, y_test = train_test_split(X_normed, y_ravel, test_size=0.2, random_state=42,shuffle=True)

# Oversample the minority class (dead patients)
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
def create_nn(learning_rate=0.001):
    model = Sequential([Input(shape=(3,)),
                        Dense(64, activation="relu"),
                        Dense(32, activation="relu"), 
                        Dense(1, activation="sigmoid")]) 
    
    model.compile(optimizer = Adam(learning_rate=learning_rate),
                  loss = "binary_crossentropy",
                  metrics = ["accuracy"])
                  
    return model

# %%
# Keras wrapper -> use gridsearchcv with neuralnet

nn = KerasClassifier(model=create_nn)

# %%
# Gridsearchcv

param_grid = {
    'model__learning_rate': [0.001, 0.01],
    'batch_size': [64, 128, 256]
}

grid_search = GridSearchCV(
    estimator=nn,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=5,
    n_jobs=-1
) 

# early stop
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

grid_search.fit(
    X_train_smote,
    y_train_smote,
    epochs=200,
    callbacks=[early_stop]
)

print("Best Parameters:", grid_search.best_params_)
print("Best ROC-AUC:", grid_search.best_score_)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\joblib\externals\loky\process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Epoch 1/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 2s 785us/step - accuracy: 0.6412 - loss: 0.6213
# Epoch 2/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6497 - loss: 0.6116
# Epoch 3/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6520 - loss: 0.6102
# Epoch 4/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step - accuracy: 0.6537 - loss: 0.6095
# Epoch 5/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 791us/step - accuracy: 0.6521 - loss: 0.6113
# Epoch 6/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 768us/step - accuracy: 0.6519 - loss: 0.6107
# Epoch 7/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6520 - loss: 0.6094
# Epoch 8/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 783us/step - accuracy: 0.6519 - loss: 0.6091
# Epoch 9/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6502 - loss: 0.6115
# Epoch 10/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6508 - loss: 0.6103
# Epoch 11/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6504 - loss: 0.6113
# Epoch 12/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6518 - loss: 0.6089
# Epoch 13/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6523 - loss: 0.6089
# Epoch 14/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6513 - loss: 0.6092
# Epoch 15/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6507 - loss: 0.6101
# Epoch 16/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6528 - loss: 0.6091
# Epoch 17/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6499 - loss: 0.6104
# Epoch 18/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6515 - loss: 0.6096
# Epoch 19/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6509 - loss: 0.6099
# Epoch 20/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6509 - loss: 0.6105
# Epoch 21/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6527 - loss: 0.6086
# Epoch 22/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 782us/step - accuracy: 0.6518 - loss: 0.6100
# Epoch 23/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6529 - loss: 0.6078
# Epoch 24/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 783us/step - accuracy: 0.6526 - loss: 0.6087
# Epoch 25/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6527 - loss: 0.6091
# Epoch 26/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6515 - loss: 0.6099
# Epoch 27/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6522 - loss: 0.6085
# Epoch 28/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6522 - loss: 0.6087
# Epoch 29/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 783us/step - accuracy: 0.6530 - loss: 0.6078
# Epoch 30/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6507 - loss: 0.6095
# Epoch 31/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6511 - loss: 0.6101
# Epoch 32/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6532 - loss: 0.6089
# Epoch 33/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6520 - loss: 0.6086
# Epoch 34/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.6521 - loss: 0.6091
# Epoch 35/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6509 - loss: 0.6093
# Epoch 36/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6522 - loss: 0.6078
# Epoch 37/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.6523 - loss: 0.6077
# Epoch 38/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6502 - loss: 0.6099
# Epoch 39/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6519 - loss: 0.6079
# Epoch 40/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.6523 - loss: 0.6088
# Epoch 41/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6532 - loss: 0.6071
# Epoch 42/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 774us/step - accuracy: 0.6520 - loss: 0.6090
# Epoch 43/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 771us/step - accuracy: 0.6504 - loss: 0.6093
# Epoch 44/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 782us/step - accuracy: 0.6528 - loss: 0.6080
# Epoch 45/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6522 - loss: 0.6087
# Epoch 46/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6524 - loss: 0.6083
# Epoch 47/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 774us/step - accuracy: 0.6524 - loss: 0.6081
# Epoch 48/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 774us/step - accuracy: 0.6520 - loss: 0.6078
# Epoch 49/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6525 - loss: 0.6084
# Epoch 50/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 768us/step - accuracy: 0.6518 - loss: 0.6075
# Epoch 51/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6507 - loss: 0.6084
# Epoch 52/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 782us/step - accuracy: 0.6537 - loss: 0.6068
# Epoch 53/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6496 - loss: 0.6095
# Epoch 54/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6526 - loss: 0.6070
# Epoch 55/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6498 - loss: 0.6099
# Epoch 56/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.6512 - loss: 0.6088
# Epoch 57/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.6537 - loss: 0.6077
# Epoch 58/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6528 - loss: 0.6075
# Epoch 59/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.6517 - loss: 0.6085
# Epoch 60/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6524 - loss: 0.6079
# Epoch 61/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.6531 - loss: 0.6073
# Epoch 62/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 782us/step - accuracy: 0.6537 - loss: 0.6066
# Epoch 63/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6533 - loss: 0.6067
# Epoch 64/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 774us/step - accuracy: 0.6510 - loss: 0.6098
# Epoch 65/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6520 - loss: 0.6080
# Epoch 66/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6532 - loss: 0.6073
# Epoch 67/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6517 - loss: 0.6083
# Epoch 68/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.6496 - loss: 0.6077
# Epoch 69/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6532 - loss: 0.6063
# Epoch 70/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6515 - loss: 0.6088
# Epoch 71/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6515 - loss: 0.6079
# Epoch 72/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6515 - loss: 0.6084
# Epoch 73/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6514 - loss: 0.6078
# Epoch 74/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.6533 - loss: 0.6075
# Epoch 75/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 774us/step - accuracy: 0.6519 - loss: 0.6084
# Epoch 76/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6543 - loss: 0.6069
# Epoch 77/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6522 - loss: 0.6076
# Epoch 78/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6529 - loss: 0.6076
# Epoch 79/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 782us/step - accuracy: 0.6539 - loss: 0.6065
# Epoch 80/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.6532 - loss: 0.6072
# Epoch 81/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6535 - loss: 0.6072
# Epoch 82/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.6523 - loss: 0.6086
# Epoch 83/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.6514 - loss: 0.6079
# Epoch 84/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 774us/step - accuracy: 0.6528 - loss: 0.6078
# Epoch 85/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6489 - loss: 0.6102
# Epoch 86/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6519 - loss: 0.6071
# Epoch 87/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6524 - loss: 0.6070
# Epoch 88/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 774us/step - accuracy: 0.6536 - loss: 0.6056
# Epoch 89/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6511 - loss: 0.6084
# Epoch 90/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6525 - loss: 0.6076
# Epoch 91/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 782us/step - accuracy: 0.6524 - loss: 0.6079
# Epoch 92/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6526 - loss: 0.6075
# Epoch 93/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 769us/step - accuracy: 0.6519 - loss: 0.6083
# Epoch 94/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step - accuracy: 0.6520 - loss: 0.6090
# Epoch 95/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6524 - loss: 0.6075
# Epoch 96/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6544 - loss: 0.6069
# Epoch 97/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6526 - loss: 0.6068
# Epoch 98/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6527 - loss: 0.6064
# Epoch 99/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 774us/step - accuracy: 0.6525 - loss: 0.6071
# Epoch 100/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6560 - loss: 0.6054
# Epoch 101/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6514 - loss: 0.6083
# Epoch 102/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6540 - loss: 0.6065
# Epoch 103/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 795us/step - accuracy: 0.6534 - loss: 0.6077
# Epoch 104/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 823us/step - accuracy: 0.6538 - loss: 0.6068
# Epoch 105/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6523 - loss: 0.6081
# Epoch 106/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6520 - loss: 0.6087
# Epoch 107/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 783us/step - accuracy: 0.6521 - loss: 0.6083
# Epoch 108/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6515 - loss: 0.6084
# Epoch 109/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 813us/step - accuracy: 0.6542 - loss: 0.6062
# Epoch 110/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6524 - loss: 0.6075
# Epoch 111/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.6525 - loss: 0.6077
# Epoch 112/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6531 - loss: 0.6062
# Epoch 113/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.6520 - loss: 0.6079
# Epoch 114/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6528 - loss: 0.6074
# Epoch 115/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 768us/step - accuracy: 0.6540 - loss: 0.6065
# Epoch 116/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step - accuracy: 0.6539 - loss: 0.6060
# Epoch 117/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 770us/step - accuracy: 0.6539 - loss: 0.6067
# Epoch 118/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6520 - loss: 0.6074
# Epoch 119/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6553 - loss: 0.6042
# Epoch 120/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 770us/step - accuracy: 0.6522 - loss: 0.6075
# Epoch 121/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6555 - loss: 0.6053
# Epoch 122/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step - accuracy: 0.6544 - loss: 0.6076
# Epoch 123/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6543 - loss: 0.6073
# Epoch 124/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 771us/step - accuracy: 0.6541 - loss: 0.6068
# Epoch 125/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step - accuracy: 0.6531 - loss: 0.6067
# Epoch 126/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 770us/step - accuracy: 0.6545 - loss: 0.6069
# Epoch 127/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 769us/step - accuracy: 0.6527 - loss: 0.6065
# Epoch 128/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 771us/step - accuracy: 0.6534 - loss: 0.6070
# Epoch 129/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step - accuracy: 0.6529 - loss: 0.6059
# Epoch 130/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6530 - loss: 0.6069
# Epoch 131/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step - accuracy: 0.6517 - loss: 0.6069
# Epoch 132/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6530 - loss: 0.6071
# Epoch 133/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6558 - loss: 0.6056
# Epoch 134/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6544 - loss: 0.6073
# Epoch 135/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 768us/step - accuracy: 0.6542 - loss: 0.6069
# Epoch 136/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step - accuracy: 0.6538 - loss: 0.6076
# Epoch 137/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.6527 - loss: 0.6073
# Epoch 138/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6518 - loss: 0.6084
# Epoch 139/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 768us/step - accuracy: 0.6511 - loss: 0.6073
# Epoch 140/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6530 - loss: 0.6065
# Epoch 141/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6541 - loss: 0.6061
# Epoch 142/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.6520 - loss: 0.6075
# Epoch 143/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6536 - loss: 0.6057
# Epoch 144/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6530 - loss: 0.6067
# Epoch 145/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6542 - loss: 0.6057
# Epoch 146/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6535 - loss: 0.6074
# Epoch 147/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 771us/step - accuracy: 0.6553 - loss: 0.6057
# Epoch 148/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 783us/step - accuracy: 0.6557 - loss: 0.6046
# Epoch 149/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6536 - loss: 0.6063
# Epoch 150/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 770us/step - accuracy: 0.6566 - loss: 0.6053
# Epoch 151/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step - accuracy: 0.6552 - loss: 0.6036
# Epoch 152/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.6552 - loss: 0.6050
# Epoch 153/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 788us/step - accuracy: 0.6540 - loss: 0.6061
# Epoch 154/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 785us/step - accuracy: 0.6546 - loss: 0.6056
# Epoch 155/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 785us/step - accuracy: 0.6531 - loss: 0.6074
# Epoch 156/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 795us/step - accuracy: 0.6544 - loss: 0.6057
# Epoch 157/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 783us/step - accuracy: 0.6541 - loss: 0.6050
# Epoch 158/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6560 - loss: 0.6050
# Epoch 159/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.6548 - loss: 0.6067
# Epoch 160/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6534 - loss: 0.6073
# Epoch 161/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6543 - loss: 0.6060
# Epoch 162/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6538 - loss: 0.6062
# Epoch 163/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6540 - loss: 0.6063
# Epoch 164/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6536 - loss: 0.6065
# Epoch 165/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6513 - loss: 0.6067
# Epoch 166/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.6551 - loss: 0.6046
# Epoch 167/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 782us/step - accuracy: 0.6530 - loss: 0.6074
# Epoch 168/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 774us/step - accuracy: 0.6535 - loss: 0.6066
# Epoch 169/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 771us/step - accuracy: 0.6543 - loss: 0.6068
# Epoch 170/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6532 - loss: 0.6068
# Epoch 171/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - accuracy: 0.6524 - loss: 0.6072
# Epoch 172/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.6533 - loss: 0.6071
# Epoch 173/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6533 - loss: 0.6066
# Epoch 174/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6560 - loss: 0.6055
# Epoch 175/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6525 - loss: 0.6069
# Epoch 176/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6555 - loss: 0.6055
# Epoch 177/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 782us/step - accuracy: 0.6542 - loss: 0.6066
# Epoch 178/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 788us/step - accuracy: 0.6537 - loss: 0.6072
# Epoch 179/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6542 - loss: 0.6058
# Epoch 180/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6540 - loss: 0.6060
# Epoch 181/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6536 - loss: 0.6065
# Epoch 182/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6525 - loss: 0.6065
# Epoch 183/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6551 - loss: 0.6055
# Epoch 184/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6538 - loss: 0.6073
# Epoch 185/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6522 - loss: 0.6085
# Epoch 186/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 798us/step - accuracy: 0.6567 - loss: 0.6053
# Epoch 187/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6569 - loss: 0.6050
# Epoch 188/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - accuracy: 0.6537 - loss: 0.6062
# Epoch 189/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.6559 - loss: 0.6065
# Epoch 190/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6553 - loss: 0.6048
# Epoch 191/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - accuracy: 0.6549 - loss: 0.6057
# Epoch 192/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 773us/step - accuracy: 0.6552 - loss: 0.6053
# Epoch 193/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - accuracy: 0.6569 - loss: 0.6047
# Epoch 194/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 771us/step - accuracy: 0.6562 - loss: 0.6052
# Epoch 195/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6548 - loss: 0.6057
# Epoch 196/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 778us/step - accuracy: 0.6565 - loss: 0.6052
# Epoch 197/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 779us/step - accuracy: 0.6538 - loss: 0.6064
# Epoch 198/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 784us/step - accuracy: 0.6545 - loss: 0.6048
# Epoch 199/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 786us/step - accuracy: 0.6558 - loss: 0.6062
# Epoch 200/200
# 1277/1277 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - accuracy: 0.6556 - loss: 0.6058
# Best Parameters: {'batch_size': 128, 'model__learning_rate': 0.001}
# Best ROC-AUC: 0.7122604915562782

# %%
# train on 3 splits
for test_size in [0.2,0.5, 0.8]:
    X_train, X_test, y_train, y_test = train_test_split(X_normed, y_ravel, test_size=test_size, random_state=42,shuffle=True)
    
    # create model with optimal learning rate
    nn_opt = create_nn(
        learning_rate=grid_search.best_params_['model__learning_rate']
    )
    
    nn_opt.fit(X_train, y_train,
               batch_size=grid_search.best_params_['batch_size'],
               epochs=200,
               validation_split=0.2,
               callbacks=[early_stop])
    
    y_pred = nn_opt.predict(X_test)
    y_pred_proba = nn_opt.predict(X_test).ravel()
    
    print("Train="+str(round(1-test_size)))
    print(classification_report(y_test, (nn_opt.predict(X_test) > 0.5).astype(int)))
    print(f"ROC-AUC: {roc_auc_score(y_test, y_pred_proba):.4f}")
    print(" ")
    print(" ")
# Out:
# Epoch 1/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9095 - loss: 0.3221 - val_accuracy: 0.9284 - val_loss: 0.2396
# Epoch 2/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 979us/step - accuracy: 0.9234 - loss: 0.2524 - val_accuracy: 0.9284 - val_loss: 0.2382
# Epoch 3/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 978us/step - accuracy: 0.9271 - loss: 0.2419 - val_accuracy: 0.9284 - val_loss: 0.2381
# Epoch 4/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 979us/step - accuracy: 0.9248 - loss: 0.2467 - val_accuracy: 0.9284 - val_loss: 0.2379
# Epoch 5/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 964us/step - accuracy: 0.9258 - loss: 0.2454 - val_accuracy: 0.9284 - val_loss: 0.2377
# Epoch 6/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 981us/step - accuracy: 0.9251 - loss: 0.2465 - val_accuracy: 0.9284 - val_loss: 0.2374
# Epoch 7/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 965us/step - accuracy: 0.9255 - loss: 0.2455 - val_accuracy: 0.9284 - val_loss: 0.2374
# Epoch 8/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 971us/step - accuracy: 0.9273 - loss: 0.2410 - val_accuracy: 0.9284 - val_loss: 0.2377
# Epoch 9/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 976us/step - accuracy: 0.9254 - loss: 0.2452 - val_accuracy: 0.9284 - val_loss: 0.2378
# Epoch 10/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 983us/step - accuracy: 0.9259 - loss: 0.2438 - val_accuracy: 0.9284 - val_loss: 0.2373
# Epoch 11/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 969us/step - accuracy: 0.9244 - loss: 0.2470 - val_accuracy: 0.9284 - val_loss: 0.2375
# Epoch 12/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 973us/step - accuracy: 0.9262 - loss: 0.2440 - val_accuracy: 0.9284 - val_loss: 0.2373
# Epoch 13/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 972us/step - accuracy: 0.9251 - loss: 0.2466 - val_accuracy: 0.9284 - val_loss: 0.2374
# Epoch 14/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 979us/step - accuracy: 0.9246 - loss: 0.2476 - val_accuracy: 0.9284 - val_loss: 0.2372
# Epoch 15/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 972us/step - accuracy: 0.9263 - loss: 0.2435 - val_accuracy: 0.9284 - val_loss: 0.2372
# Epoch 16/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 963us/step - accuracy: 0.9277 - loss: 0.2397 - val_accuracy: 0.9284 - val_loss: 0.2374
# Epoch 17/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 967us/step - accuracy: 0.9255 - loss: 0.2447 - val_accuracy: 0.9284 - val_loss: 0.2375
# Epoch 18/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 979us/step - accuracy: 0.9257 - loss: 0.2459 - val_accuracy: 0.9284 - val_loss: 0.2375
# Epoch 19/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 974us/step - accuracy: 0.9250 - loss: 0.2459 - val_accuracy: 0.9284 - val_loss: 0.2374
# Epoch 20/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 971us/step - accuracy: 0.9245 - loss: 0.2484 - val_accuracy: 0.9284 - val_loss: 0.2372
# Epoch 21/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 981us/step - accuracy: 0.9261 - loss: 0.2442 - val_accuracy: 0.9284 - val_loss: 0.2375
# Epoch 22/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 970us/step - accuracy: 0.9247 - loss: 0.2455 - val_accuracy: 0.9284 - val_loss: 0.2376
# Epoch 23/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 955us/step - accuracy: 0.9261 - loss: 0.2439 - val_accuracy: 0.9284 - val_loss: 0.2378
# Epoch 24/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 989us/step - accuracy: 0.9266 - loss: 0.2429 - val_accuracy: 0.9284 - val_loss: 0.2372
# Epoch 25/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 971us/step - accuracy: 0.9246 - loss: 0.2466 - val_accuracy: 0.9284 - val_loss: 0.2379
# Epoch 26/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 973us/step - accuracy: 0.9276 - loss: 0.2400 - val_accuracy: 0.9284 - val_loss: 0.2377
# Epoch 27/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 977us/step - accuracy: 0.9245 - loss: 0.2474 - val_accuracy: 0.9284 - val_loss: 0.2372
# Epoch 28/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 969us/step - accuracy: 0.9252 - loss: 0.2450 - val_accuracy: 0.9284 - val_loss: 0.2373
# Epoch 29/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 981us/step - accuracy: 0.9252 - loss: 0.2457 - val_accuracy: 0.9284 - val_loss: 0.2385
# Epoch 30/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 963us/step - accuracy: 0.9278 - loss: 0.2391 - val_accuracy: 0.9284 - val_loss: 0.2375
# Epoch 31/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 972us/step - accuracy: 0.9255 - loss: 0.2452 - val_accuracy: 0.9284 - val_loss: 0.2376
# Epoch 32/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 976us/step - accuracy: 0.9252 - loss: 0.2464 - val_accuracy: 0.9284 - val_loss: 0.2373
# Epoch 33/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - accuracy: 0.9250 - loss: 0.2452 - val_accuracy: 0.9284 - val_loss: 0.2372
# Epoch 34/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 989us/step - accuracy: 0.9254 - loss: 0.2444 - val_accuracy: 0.9284 - val_loss: 0.2375
# Epoch 35/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 969us/step - accuracy: 0.9257 - loss: 0.2442 - val_accuracy: 0.9284 - val_loss: 0.2389
# Epoch 36/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 962us/step - accuracy: 0.9275 - loss: 0.2402 - val_accuracy: 0.9284 - val_loss: 0.2381
# Epoch 37/200
# 552/552 ━━━━━━━━━━━━━━━━━━━━ 1s 991us/step - accuracy: 0.9263 - loss: 0.2435 - val_accuracy: 0.9284 - val_loss: 0.2373
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 0s 410us/step
# Train=1
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 0s 416us/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1613
#            1       0.93      1.00      0.96     20428
#
#     accuracy                           0.93     22041
#    macro avg       0.46      0.50      0.48     22041
# weighted avg       0.86      0.93      0.89     22041
#
# ROC-AUC: 0.7015
#
#
# Epoch 1/200
# C:\Users\Ha Duong\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Ha Duong\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Ha Duong\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8647 - loss: 0.3631 - val_accuracy: 0.9298 - val_loss: 0.2390
# Epoch 2/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9267 - loss: 0.2455 - val_accuracy: 0.9298 - val_loss: 0.2352
# Epoch 3/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9264 - loss: 0.2448 - val_accuracy: 0.9298 - val_loss: 0.2356
# Epoch 4/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9262 - loss: 0.2446 - val_accuracy: 0.9298 - val_loss: 0.2342
# Epoch 5/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - accuracy: 0.9259 - loss: 0.2441 - val_accuracy: 0.9298 - val_loss: 0.2340
# Epoch 6/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9274 - loss: 0.2421 - val_accuracy: 0.9298 - val_loss: 0.2345
# Epoch 7/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9252 - loss: 0.2453 - val_accuracy: 0.9298 - val_loss: 0.2342
# Epoch 8/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - accuracy: 0.9265 - loss: 0.2433 - val_accuracy: 0.9298 - val_loss: 0.2353
# Epoch 9/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9245 - loss: 0.2476 - val_accuracy: 0.9298 - val_loss: 0.2341
# Epoch 10/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9261 - loss: 0.2435 - val_accuracy: 0.9298 - val_loss: 0.2355
# Epoch 11/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9224 - loss: 0.2512 - val_accuracy: 0.9298 - val_loss: 0.2346
# Epoch 12/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9257 - loss: 0.2446 - val_accuracy: 0.9298 - val_loss: 0.2341
# Epoch 13/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9240 - loss: 0.2491 - val_accuracy: 0.9298 - val_loss: 0.2338
# Epoch 14/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9294 - loss: 0.2359 - val_accuracy: 0.9298 - val_loss: 0.2339
# Epoch 15/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9258 - loss: 0.2440 - val_accuracy: 0.9298 - val_loss: 0.2339
# Epoch 16/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9256 - loss: 0.2443 - val_accuracy: 0.9298 - val_loss: 0.2341
# Epoch 17/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9253 - loss: 0.2452 - val_accuracy: 0.9298 - val_loss: 0.2341
# Epoch 18/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9256 - loss: 0.2463 - val_accuracy: 0.9298 - val_loss: 0.2346
# Epoch 19/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9265 - loss: 0.2429 - val_accuracy: 0.9298 - val_loss: 0.2339
# Epoch 20/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9256 - loss: 0.2446 - val_accuracy: 0.9298 - val_loss: 0.2343
# Epoch 21/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9266 - loss: 0.2422 - val_accuracy: 0.9298 - val_loss: 0.2338
# Epoch 22/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9266 - loss: 0.2421 - val_accuracy: 0.9298 - val_loss: 0.2340
# Epoch 23/200
# 345/345 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9249 - loss: 0.2472 - val_accuracy: 0.9298 - val_loss: 0.2340
# 1722/1722 ━━━━━━━━━━━━━━━━━━━━ 1s 415us/step
# 1722/1722 ━━━━━━━━━━━━━━━━━━━━ 1s 404us/step
# Train=0
# 1722/1722 ━━━━━━━━━━━━━━━━━━━━ 1s 408us/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      4062
#            1       0.93      1.00      0.96     51040
#
#     accuracy                           0.93     55102
#    macro avg       0.46      0.50      0.48     55102
# weighted avg       0.86      0.93      0.89     55102
#
# ROC-AUC: 0.7043
#
#
# Epoch 1/200
# C:\Users\Ha Duong\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Ha Duong\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Ha Duong\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8712 - loss: 0.4174 - val_accuracy: 0.9285 - val_loss: 0.2475
# Epoch 2/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9294 - loss: 0.2399 - val_accuracy: 0.9285 - val_loss: 0.2423
# Epoch 3/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9319 - loss: 0.2329 - val_accuracy: 0.9285 - val_loss: 0.2400
# Epoch 4/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9325 - loss: 0.2297 - val_accuracy: 0.9285 - val_loss: 0.2381
# Epoch 5/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9298 - loss: 0.2357 - val_accuracy: 0.9285 - val_loss: 0.2374
# Epoch 6/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9276 - loss: 0.2384 - val_accuracy: 0.9285 - val_loss: 0.2375
# Epoch 7/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9292 - loss: 0.2355 - val_accuracy: 0.9285 - val_loss: 0.2375
# Epoch 8/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9274 - loss: 0.2398 - val_accuracy: 0.9285 - val_loss: 0.2377
# Epoch 9/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9313 - loss: 0.2321 - val_accuracy: 0.9285 - val_loss: 0.2378
# Epoch 10/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9281 - loss: 0.2395 - val_accuracy: 0.9285 - val_loss: 0.2388
# Epoch 11/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9288 - loss: 0.2352 - val_accuracy: 0.9285 - val_loss: 0.2381
# Epoch 12/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9295 - loss: 0.2336 - val_accuracy: 0.9285 - val_loss: 0.2376
# Epoch 13/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9281 - loss: 0.2366 - val_accuracy: 0.9285 - val_loss: 0.2380
# Epoch 14/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9285 - loss: 0.2359 - val_accuracy: 0.9285 - val_loss: 0.2374
# Epoch 15/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9304 - loss: 0.2333 - val_accuracy: 0.9285 - val_loss: 0.2403
# Epoch 16/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9276 - loss: 0.2395 - val_accuracy: 0.9285 - val_loss: 0.2380
# Epoch 17/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9287 - loss: 0.2372 - val_accuracy: 0.9285 - val_loss: 0.2378
# Epoch 18/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9288 - loss: 0.2371 - val_accuracy: 0.9285 - val_loss: 0.2383
# Epoch 19/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9308 - loss: 0.2304 - val_accuracy: 0.9285 - val_loss: 0.2375
# Epoch 20/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9326 - loss: 0.2255 - val_accuracy: 0.9285 - val_loss: 0.2405
# Epoch 21/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9306 - loss: 0.2321 - val_accuracy: 0.9285 - val_loss: 0.2389
# Epoch 22/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9305 - loss: 0.2332 - val_accuracy: 0.9285 - val_loss: 0.2382
# Epoch 23/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9271 - loss: 0.2387 - val_accuracy: 0.9285 - val_loss: 0.2379
# Epoch 24/200
# 138/138 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9298 - loss: 0.2344 - val_accuracy: 0.9285 - val_loss: 0.2385
# 2756/2756 ━━━━━━━━━━━━━━━━━━━━ 1s 456us/step
# 2756/2756 ━━━━━━━━━━━━━━━━━━━━ 1s 407us/step
# Train=0
# 2756/2756 ━━━━━━━━━━━━━━━━━━━━ 1s 408us/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      6533
#            1       0.93      1.00      0.96     81631
#
#     accuracy                           0.93     88164
#    macro avg       0.46      0.50      0.48     88164
# weighted avg       0.86      0.93      0.89     88164
#
# ROC-AUC: 0.7045
# C:\Users\Ha Duong\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Ha Duong\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Ha Duong\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# save the model

dump(nn_opt, "trained/nn_opt_SEPSIS.joblib")
# Out:
# ['trained/nn_opt_SEPSIS.joblib']

# %% [markdown]
# ## <b>RandomForest</b>

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score
from imblearn.over_sampling import SMOTE

# %%
# Split 80/20 train/test

y_ravel = y_n.values.ravel()

X_train, X_test, y_train, y_test = train_test_split(X_normed, y_ravel, test_size=0.2, random_state=42,shuffle=True)

# Oversample the minority class (dead patients)
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
# gridsearchcv
param_grid = {
    'n_estimators': [50,100,200],
    'max_depth': [10, 20],
    'min_samples_split': [2, 5]
}

grid_search = GridSearchCV(
    RandomForestClassifier(random_state=42), 
    param_grid, 
    cv=5, 
    scoring='roc_auc',
    verbose=1,
    n_jobs=-1
)

grid_search.fit(X_train_smote, y_train_smote)
print("Best Parameters:", grid_search.best_params_)
print("Best ROC-AUC:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Best Parameters: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 200}
# Best ROC-AUC: 0.7479761980936049

# %%
# Check most 'influential' feature to predict the target
feature_importances = grid_search.best_estimator_.feature_importances_
feature_importances
# Out:
# array([0.97542572, 0.00737341, 0.01720087])

# %%
#Train model with best parameters on 3 different splits

for test_size in [0.2,0.5, 0.8]:
    X_train, X_test, y_train, y_test = train_test_split(X_normed, y_ravel, test_size=test_size, random_state=42,shuffle=True)    
    
    rf_opt = RandomForestClassifier(**grid_search.best_params_, random_state=42)
    
    rf_opt.fit(X_train, y_train)
    
    y_pred = rf_opt.predict(X_test)
    y_pred_proba = rf_opt.predict_proba(X_test)[:,1]
    
    print("Train="+str(round(1-test_size,2)))
    print(classification_report(y_test, y_pred))
    print(f"ROC-AUC: {roc_auc_score(y_test, y_pred_proba):.4f}")
    print(" ")
    print(" ")
# Out:
# Train=0.8
#               precision    recall  f1-score   support
#
#            0       0.20      0.00      0.00      1613
#            1       0.93      1.00      0.96     20428
#
#     accuracy                           0.93     22041
#    macro avg       0.56      0.50      0.48     22041
# weighted avg       0.87      0.93      0.89     22041
#
# ROC-AUC: 0.6901
#
#
# Train=0.5
#               precision    recall  f1-score   support
#
#            0       0.20      0.00      0.00      4062
#            1       0.93      1.00      0.96     51040
#
#     accuracy                           0.93     55102
#    macro avg       0.56      0.50      0.48     55102
# weighted avg       0.87      0.93      0.89     55102
#
# ROC-AUC: 0.6848
#
#
# Train=0.2
#               precision    recall  f1-score   support
#
#            0       0.07      0.00      0.00      6533
#            1       0.93      1.00      0.96     81631
#
#     accuracy                           0.92     88164
#    macro avg       0.50      0.50      0.48     88164
# weighted avg       0.86      0.92      0.89     88164
#
# ROC-AUC: 0.6751

# %%
# save the model

dump(rf_opt, "trained/rf_opt_SEPSIS.joblib")
# Out:
# ['trained/rf_opt_SEPSIS.joblib']

# %% [markdown]
# ## <b>SGDClassifier (SVM approximation)</b>

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Split 80/20 train/test

y_ravel = y_n.values.ravel()

# splitting NORMED data
X_train, X_test, y_train, y_test = train_test_split(X_normed, y_ravel, test_size=0.2, random_state=42,shuffle=True)

# Oversample the minority class (dead patients)
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# %%
# base model
sgd = SGDClassifier(
    learning_rate='optimal',
    penalty='elasticnet',
    max_iter=1000,
    random_state=42
)

#gridsearch
param_grid = {
    'alpha' : [1e-5, 1e-3, 1e-1],
    'l1_ratio': [0.15,0.5, 0.85],
    'tol' : [1e-5, 1e-6],
    'loss': ['log_loss']
}

grid_search = GridSearchCV(
    estimator=sgd,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=5,
    verbose=1,
    n_jobs=-1
)

grid_search.fit(X_train_smote, y_train_smote)

# Best parameters and evaluation
print("Best Parameters:", grid_search.best_params_)
print("Best ROC-AUC:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best Parameters: {'alpha': 0.001, 'l1_ratio': 0.15, 'loss': 'log_loss', 'tol': 1e-05}
# Best ROC-AUC: 0.7076167741122281

# %%
for test_size in [0.2,0.5, 0.8]:
    X_train, X_test, y_train, y_test = train_test_split(X_normed, y_ravel, test_size=test_size, random_state=42,shuffle=True)    
    
    sgd_opt = SGDClassifier(
        **grid_search.best_params_, 
        learning_rate='optimal',
        penalty='elasticnet',
        max_iter=1000,
        random_state=42
    )
    
    sgd_opt.fit(X_train, y_train)
    
    y_pred = sgd_opt.predict(X_test)
    y_pred_proba = sgd_opt.predict_proba(X_test)[:,1]
    
    print("Train="+str(round(1 - test_size, 2)))
    print(classification_report(y_test, y_pred, zero_division=0))
    print(f"ROC-AUC: {roc_auc_score(y_test, y_pred_proba):.4f}")
    print(" ")
    print(" ")
# Out:
# Train=0.8
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1613
#            1       0.93      1.00      0.96     20428
#
#     accuracy                           0.93     22041
#    macro avg       0.46      0.50      0.48     22041
# weighted avg       0.86      0.93      0.89     22041
#
# ROC-AUC: 0.6996
#
#
# Train=0.5
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      4062
#            1       0.93      1.00      0.96     51040
#
#     accuracy                           0.93     55102
#    macro avg       0.46      0.50      0.48     55102
# weighted avg       0.86      0.93      0.89     55102
#
# ROC-AUC: 0.7039
#
#
# Train=0.2
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      6533
#            1       0.93      1.00      0.96     81631
#
#     accuracy                           0.93     88164
#    macro avg       0.46      0.50      0.48     88164
# weighted avg       0.86      0.93      0.89     88164
#
# ROC-AUC: 0.7024

# %%
# save the model

dump(sgd_opt, "trained/sgd_opt_SEPSIS.joblib")
# Out:
# ['trained/sgd_opt_SEPSIS.joblib']

# %% [markdown]
# ## <b>Ensemble (Meta-model = SVM)</b>

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_auc_score

# %%
# split data
X_train, X_test, y_train, y_test = train_test_split(X_normed, y_ravel, test_size=0.2, random_state=42,shuffle=True)    

# all pretrained models
base_models = [sgd_opt, rf_opt, nn_opt, xgb_opt]

# make meta features
meta_trainl = []
meta_testl = []

for model in base_models:
    if hasattr(model, "predict_proba"):
        meta_trainl.append(model.predict_proba(X_train)[:,1])
        meta_testl.append(model.predict_proba(X_test)[:,1])
    else:
        meta_trainl.append(model.predict(X_train).ravel())
        meta_testl.append(model.predict(X_test).ravel())    #NN doesnt have predict proba

meta_train = np.array(meta_trainl).T
meta_test = np.array(meta_testl).T
# Out:
# 2756/2756 ━━━━━━━━━━━━━━━━━━━━ 1s 406us/step
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 0s 430us/step

# %%
svm_meta = SVC(kernel='rbf', probability=True, random_state=42)

svm_meta.fit(meta_train, y_train)

param_grid = {
    'C' : [0.1, 1, 10],
    'gamma': [0.01, 0.1, 1]
}

grid_search = GridSearchCV(
    estimator=svm_meta,
    param_grid=param_grid,
    scoring='roc_auc',
    cv=5,  # Inner cross-validation
    verbose=2,
    n_jobs=-1
)

# Fit the meta-model using GridSearchCV
grid_search.fit(meta_train, y_train)

# Best parameters and evaluation
print("Best Parameters:", grid_search.best_params_)
print("Best ROC-AUC:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# Best Parameters: {'C': 0.1, 'gamma': 0.1}
# Best ROC-AUC: 0.7053380984089033

# %%
for test_size in [0.2,0.5, 0.8]:
    # split data
    X_train, X_test, y_train, y_test = train_test_split(X_normed, y_ravel, test_size=test_size, random_state=42,shuffle=True)    

    meta_trainl=[]
    meta_testl=[]

    for model in base_models:
        if hasattr(model, "predict_proba"):
            meta_trainl.append(model.predict_proba(X_train)[:,1])
            meta_testl.append(model.predict_proba(X_test)[:,1])
        else:
            meta_trainl.append(model.predict(X_train).ravel())
            meta_testl.append(model.predict(X_test).ravel())    #NN doesnt have predict proba
    
    meta_train = np.array(meta_trainl).T
    meta_test = np.array(meta_testl).T
    
    svm_meta_opt = SVC(
        **grid_search.best_params_, 
        probability=True,
        random_state=42
    )
    
    svm_meta_opt.fit(meta_train, y_train)
    
    y_pred = svm_meta_opt.predict(meta_test)
    y_pred_proba = svm_meta_opt.predict_proba(meta_test)[:,1]
    
    print("Train="+str(round(1 - test_size, 2)))
    print(classification_report(y_test, y_pred, zero_division=0))
    print(f"ROC-AUC: {roc_auc_score(y_test, y_pred_proba):.4f}")
    print(" ")
    print(" ")
# Out:
# 2756/2756 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 1s 932us/step
# Train=0.8
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1613
#            1       0.93      1.00      0.96     20428
#
#     accuracy                           0.93     22041
#    macro avg       0.46      0.50      0.48     22041
# weighted avg       0.86      0.93      0.89     22041
#
# ROC-AUC: 0.6997
#
#
# 1722/1722 ━━━━━━━━━━━━━━━━━━━━ 2s 819us/step
# 1722/1722 ━━━━━━━━━━━━━━━━━━━━ 2s 837us/step
# Train=0.5
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      4062
#            1       0.93      1.00      0.96     51040
#
#     accuracy                           0.93     55102
#    macro avg       0.46      0.50      0.48     55102
# weighted avg       0.86      0.93      0.89     55102
#
# ROC-AUC: 0.3457
#
#
# 689/689 ━━━━━━━━━━━━━━━━━━━━ 1s 941us/step
# 2756/2756 ━━━━━━━━━━━━━━━━━━━━ 2s 823us/step
# Train=0.2
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      6533
#            1       0.93      1.00      0.96     81631
#
#     accuracy                           0.93     88164
#    macro avg       0.46      0.50      0.48     88164
# weighted avg       0.86      0.93      0.89     88164
#
# ROC-AUC: 0.6661

# %%
# save the model

dump(svm_meta_opt, "trained/svm_meta_opt_SEPSIS.joblib")
# Out:
# ['trained/svm_meta_opt_SEPSIS.joblib']
